# %% [markdown]
# <h1> Recommendations </h1>

# %% [markdown]
# My first thought is to try and make some sort of cosine similarity system to match each user to recipes where they have the highest similarity scores with that recipes ingredients.

# %%
# Importing the variables I need to use from previous notebook + libraries
# %store -r mealdf
# %store -r userdf
import pandas as pd
import numpy as np

# %%
# Using sklearn to employ cosine similarity
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# /Users/jantmann17/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# In order to get similarity scores, we need to employ TF-IDF (term frequency - inverse document frequency). I learned some of this at my internship working on some NLP last summer. TF-IDF will give a score for each ingredient measuring its importance in a document. By making a document matrix using TF-IDF for both datasets, we will be able to compare them using cosine similarity and thus make meal recommendations.

# %%
# Setting up the document-term matrices for both datasets

meal_ingredients = [] # initialize an empty list for meal ingredients
# iterate through each element of the ingredients column in the meal dataset
for ingredients in mealdf['ingredients'] :
    meal_ingredients.extend(ingredients) # adding all of the ingredients to the empty list

unique_ingredients = set(meal_ingredients) # making a set of unique ingredients

# it's only 'stringredients' because I like terrible puns...
# joining ingredients of each meal into a single string and separating by spaces
mealdf['stringredients'] = mealdf['ingredients'].apply(lambda x : ' '.join(x))

# using the tfidf module preprocesses the ingredients (lists of strings)
tfidf = TfidfVectorizer(stop_words='english', vocabulary = unique_ingredients)
doc_mat_meals = tfidf.fit_transform(mealdf['stringredients']) # setting up document matrix for meal data

userdf['liked_stringredients'] = userdf['ingredients'].apply(lambda x: ' '.join(x))
doc_mat_users = tfidf.transform(userdf['liked_stringredients']) # setting up document matrix for user data
# Out:
# /Users/jantmann17/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:1322: UserWarning: Upper case characters found in vocabulary while 'lowercase' is True. These entries will not be matched with any documents
#   warnings.warn(

# %%
# calculating similarity scores using cosine similarity across the two different document term matrices
similarity_scores = cosine_similarity(doc_mat_users, doc_mat_meals)

# %%
# creating a dataframe that allows us to visualize the similarity scores comparing the users and the meals
similarity_df = pd.DataFrame(similarity_scores, columns = mealdf['recipeName'], index = userdf['user_name'])
similarity_df
# Out:
# recipeName           Revolutionary Mac & Cheese  Chicago Chicken  \
# user_name
# Apple John                             0.023973         0.142430
# Shanelly Bazaldua                      0.000000         0.164345
# Peyton Joseph                          0.040113         0.073982
# Harshani Dharmadasa                    0.020418         0.121305
# Koma Gandy                             0.011551         0.104341
# ...                                         ...              ...
# Melvin Skochdopole                     0.032441         0.097203
# Stacey Peterson                        0.021313         0.081095
# Mark Cartier                           0.020039         0.147364
# Tasha Plonka                           0.039602         0.138302
# Rob Gordon                             0.027820         0.146586
#
# recipeName           Pork Chops with Balsamic Glaze  Chicken Avocado Burgers  \
# user_name
# Apple John                                 0.024170                 0.052136
# Shanelly Bazaldua                          0.000000                 0.437344
# Peyton Joseph                              0.008544                 0.138437
# Harshani Dharmadasa                        0.020585                 0.044403
# Koma Gandy                                 0.016567                 0.100245
# ...                                             ...                      ...
# Melvin Skochdopole                         0.032790                 0.106793
# Stacey Peterson                            0.040161                 0.103086
# Mark Cartier                               0.023148                 0.124754
# Tasha Plonka                               0.028904                 0.115332
# Rob Gordon                                 0.012522                 0.038311
#
# recipeName           Country Fried Steak Recipe With Gravy  Best Basic Burger  \
# user_name
# Apple John                                        0.051356           0.019094
# Shanelly Bazaldua                                 0.000000           0.000000
# Peyton Joseph                                     0.000000           0.006750
# Harshani Dharmadasa                               0.043739           0.016262
# Koma Gandy                                        0.049491           0.029746
# ...                                                    ...                ...
# Melvin Skochdopole                                0.057586           0.017325
# Stacey Peterson                                   0.050797           0.024148
# Mark Cartier                                      0.045344           0.029173
# Tasha Plonka                                      0.066629           0.033691
# Rob Gordon                                        0.006707           0.000000
#
# recipeName           Easy Garlic and Lemon Shrimp  Crockpot BBQ Beer Chicken  \
# user_name
# Apple John                               0.015908                   0.062247
# Shanelly Bazaldua                        0.000000                   0.131098
# Peyton Joseph                            0.006655                   0.066917
# Harshani Dharmadasa                      0.013549                   0.053015
# Koma Gandy                               0.007665                   0.082532
# ...                                           ...                        ...
# Melvin Skochdopole                       0.043241                   0.068904
# Stacey Peterson                          0.013253                   0.018545
# Mark Cartier                             0.029960                   0.116721
# Tasha Plonka                             0.036510                   0.105558
# Rob Gordon                               0.008069                   0.045741
#
# recipeName           BBQ Chicken Quesadillas  Black Pepper Steak  ...  \
# user_name                                                         ...
# Apple John                          0.059654            0.021644  ...
# Shanelly Bazaldua                   0.077777            0.000000  ...
# Peyton Joseph                       0.090034            0.015930  ...
# Harshani Dharmadasa                 0.050806            0.018434  ...
# Koma Gandy                          0.057214            0.069735  ...
# ...                                      ...                 ...  ...
# Melvin Skochdopole                  0.053357            0.062715  ...
# Stacey Peterson                     0.037508            0.066375  ...
# Mark Cartier                        0.091694            0.070157  ...
# Tasha Plonka                        0.066583            0.058598  ...
# Rob Gordon                          0.076095            0.011094  ...
#
# recipeName           Easy Thai Red Curry Shrimp  Thai Coconut Curry Soup  \
# user_name
# Apple John                             0.012887                 0.022430
# Shanelly Bazaldua                      0.000000                 0.047240
# Peyton Joseph                          0.005391                 0.036633
# Harshani Dharmadasa                    0.010975                 0.031848
# Koma Gandy                             0.017216                 0.067887
# ...                                         ...                      ...
# Melvin Skochdopole                     0.049117                 0.079502
# Stacey Peterson                        0.010736                 0.056597
# Mark Cartier                           0.033816                 0.076651
# Tasha Plonka                           0.039097                 0.067057
# Rob Gordon                             0.006536                 0.049017
#
# recipeName           Thai Chicken with Basil Stir Fry  \
# user_name
# Apple John                                   0.026948
# Shanelly Bazaldua                            0.056754
# Peyton Joseph                                0.028969
# Harshani Dharmadasa                          0.022951
# Koma Gandy                                   0.080505
# ...                                               ...
# Melvin Skochdopole                           0.090564
# Stacey Peterson                              0.066051
# Mark Cartier                                 0.091174
# Tasha Plonka                                 0.073068
# Rob Gordon                                   0.058888
#
# recipeName           Thai Mango and Chicken Curry  \
# user_name
# Apple John                               0.033204
# Shanelly Bazaldua                        0.110435
# Peyton Joseph                            0.044997
# Harshani Dharmadasa                      0.028279
# Koma Gandy                               0.056907
# ...                                           ...
# Melvin Skochdopole                       0.062133
# Stacey Peterson                          0.007273
# Mark Cartier                             0.087474
# Tasha Plonka                             0.071741
# Rob Gordon                               0.043409
#
# recipeName           Larb Gai Thai Chicken Skillet  \
# user_name
# Apple John                                0.137468
# Shanelly Bazaldua                         0.060196
# Peyton Joseph                             0.038666
# Harshani Dharmadasa                       0.133319
# Koma Gandy                                0.077656
# ...                                            ...
# Melvin Skochdopole                        0.095946
# Stacey Peterson                           0.127151
# Mark Cartier                              0.105627
# Tasha Plonka                              0.147556
# Rob Gordon                                0.026320
#
# recipeName           Fish Sticks with Thai Peanut Sauce  \
# user_name
# Apple John                                     0.009792
# Shanelly Bazaldua                              0.000000
# Peyton Joseph                                  0.004096
# Harshani Dharmadasa                            0.008340
# Koma Gandy                                     0.043827
# ...                                                 ...
# Melvin Skochdopole                             0.032025
# Stacey Peterson                                0.030216
# Mark Cartier                                   0.038015
# Tasha Plonka                                   0.041995
# Rob Gordon                                     0.033758
#
# recipeName           Grain-free Thai Chicken Meatballs with Coconut Red Curry Sauce {Paleo & Gluten-Free}  \
# user_name
# Apple John                                                    0.007167
# Shanelly Bazaldua                                             0.000000
# Peyton Joseph                                                 0.027293
# Harshani Dharmadasa                                           0.028312
# Koma Gandy                                                    0.044398
# ...                                                                ...
# Melvin Skochdopole                                            0.064257
# Stacey Peterson                                               0.060899
# Mark Cartier                                                  0.041060
# Tasha Plonka                                                  0.037928
# Rob Gordon                                                    0.028344
#
# recipeName           Thai Coconut Chicken Red Lentil Soup  \
# user_name
# Apple John                                       0.023275
# Shanelly Bazaldua                                0.049020
# Peyton Joseph                                    0.049806
# Harshani Dharmadasa                              0.033048
# Koma Gandy                                       0.051525
# ...                                                   ...
# Melvin Skochdopole                               0.085990
# Stacey Peterson                                  0.045983
# Mark Cartier                                     0.078979
# Tasha Plonka                                     0.063306
# Rob Gordon                                       0.021433
#
# recipeName           Thai Mushroom Curry  Thai Red Curry Mussels
# user_name
# Apple John                      0.021943                0.013500
# Shanelly Bazaldua               0.072983                0.000000
# Peyton Joseph                   0.027537                0.010319
# Harshani Dharmadasa             0.018689                0.011498
# Koma Gandy                      0.069154                0.030244
# ...                                  ...                     ...
# Melvin Skochdopole              0.079258                0.020766
# Stacey Peterson                 0.000000                0.016212
# Mark Cartier                    0.055272                0.031034
# Tasha Plonka                    0.045977                0.034250
# Rob Gordon                      0.025464                0.006847
#
# [186 rows x 16567 columns]

# %%
# Forming a dictionary that stores each user from the user data set and their top 5 meals based on similarity score df

N = 5

# create a dictionary to store the top N recommendations for each user
user_recommendations = {}

# iterate through each user and get their top 5 recommendations
for i, user in enumerate(userdf['user_name']):
    scores = list(enumerate(similarity_scores[:, i])) # creating a list of tuples, with an index and similarity score 
    scores.sort(key = lambda x: x[1], reverse = True) # sort scores in descending order, define the key as index 
    top_N = [mealdf.iloc[score[0]]['recipeName'] for score in scores[:N]] # get the top 5 recommendations 
    user_recommendations[user] = top_N # storing the recommendations in the dictionary

# %%
applejohn = user_recommendations['Apple John']
applejohn
# Out:
# ['Dijon Pork Loin',
#  'Duck Buffalo Wings',
#  'Old-Fashioned Stuffed Baked Clams',
#  'Crawfish Etouffee',
#  'Grouper with Tomatillo-and-Green Chile Chutney']
